# %% [markdown]
# # Data Wrangling Template

# %% [markdown]
# ## Gather

# %%
# I need to import all the libaries that will be used in this Notebook
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import requests
import io

import tweepy

b_token = "AAAAAAAAAAAAAAAAAAAAAKwZlQEAAAAAy9oXwUXebYrbqi8Pv7ctJw65iSc%3DUkLadTMRxkTscxN8sa5PxgMviExrP8maesTbY58yjbuy1TplB2"

client = tweepy.Client(bearer_token = b_token, wait_on_rate_limit=True)

# %%
# reading files 
# Archived twitter
enhanced = pd.read_csv('twitter-archive-enhanced.csv')

# Image predictions
r = requests.get('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv')
data = r.text
buffer = io.StringIO(data)
imagedf = pd.read_csv(buffer,sep="\t")

# %%
#enhanced = enhanced.reset_index().iterrows()  # make sure indexes pair with number of rows
# ite = 0

# for idx, row in enhanced:
#     if ite < 5 and row['retweeted_status_id'] > 0:
#         # change below this line
#         tweet = client.get_retweeters(row["tweet_id"])
#         if tweet.errors == [] and tweet.data != None:
#             print(tweet.data)
#             print("\n\n")
#         #change above this line
#             ite += 1
            
#tweet = client.get_tweet(id="888804989199671297",user_fields="public_metrics")
#print(tweet)

# %% [markdown]
# ## Assess

# %%
# Displaying data to be analysed 
# there is alot of missing data 
# description headers are too long and close to each other making it difficult to tell apart which header belongs where 
#Names sometimes abbreviated like a Instead of full sentence 
enhanced
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
# The data seems to be consistent no changes 
enhanced.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# looking at the consistancy of the data
enhanced.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
enhanced.sample()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1886  674790488185167872                    NaN                  NaN
#
#                       timestamp  \
# 1886  2015-12-10 03:19:24 +0000
#
#                                                  source  \
# 1886  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  retweeted_status_id  \
# 1886  ER... MER... GERD 13/10 https://t.co/L1puJISV1a                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1886                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1886  https://twitter.com/dog_rates/status/674790488...                13
#
#       rating_denominator  name doggo floofer pupper puppo
# 1886                  10  None  None    None   None  None

# %% [markdown]
# ### .info is a compendious summary of the dataframe
#  >It shows total coulmns which is 17.
#  > Data type
#  > The number of rows and coulumns
#  > The headers of each column
#  > memory usage

# %%
enhanced.info()
 # Quality- missing values in in_reply_to_status_id,in_reply_to_status_id,retweeted_status_id,retweeted_status_user_id,retweeted_status_timestamp,expanded_urls the total which is showing \
    #from tweet id and most of the data show a total of 2356 records meaning anything less mean missing data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
enhanced.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
# value count 
# enhanced['enhanced'].value_counts() there is an error message

# %%
# when I need to slect specific infomation from the table 

#patients.loc[patients['city'] == 'New York']
#print(len(patients.loc[patients['city'] == 'New York'])) here they were selecting 
#city newyork

# %%
# The  is missing information in certain columns and this will if we count any value

# %%
enhanced.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2351    False
# 2352    False
# 2353    False
# 2354    False
# 2355    False
# Length: 2356, dtype: bool

# %%
## Quality assesment 
# missing values in column in_reply_to_status_id,
#Names sometimes abbreviated like a Instead of full sentence 

## Tidiness assesment 

#Columns are too close to each other making it difficult to read

# %%
imagedf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5880\2164127856.py in <module>
# ----> 1 imagedf.head()
#
# NameError: name 'imagedf' is not defined

# %% [markdown]
# ## Clean

# %% [markdown]
# #### Define
#
# * We check for missing data with .insull which returns  a list or rows with empty cells

# %% [markdown]
# #### Code

# %%
# patients[patients['address'].isnull()] I think this needs to be here since
# its removing missing values part of cleaning 

# _enhanced[enhanced['in_reply_to_status_ids'].isnull()]_ eg since iit has missing values

# %% [markdown]
# #### Test

# %% [markdown]
# #### Define

# %% [markdown]
# #### Code

# %% [markdown]
# ### Test
